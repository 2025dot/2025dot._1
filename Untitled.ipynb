# %%
import numpy 
import matplotlib.pyplot as plt
import cv2

# %%
beforedata = cv2.imread("2023.png", cv2.IMREAD_GRAYSCALE)
afterdata = cv2.imread("2024.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(thresh1, cmap = "gray")

# %%
ret1, thresh1 = cv2.threshold(afterdata, 127, 255, cv2.THRESH_BINARY)
ret1
# Out:
# 127.0

# %%
ret2, thresh2 = cv2.threshold(beforedata, 150, 255, cv2.THRESH_BINARY)
ret2
# Out:
# 150.0

# %%
plt.imshow(thresh2, cmap = "gray")

# %%
plt.imshow(cv2.drawContours(beforedata, contours, -1, (0, 255, 0), 2),cmap = "gray")

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
cv2.drawContours(beforedata, contours, -1, (0, 255, 0), 2)
# Out:
# array([[ 80,  80,  80, ...,  46,  46,  46],
#        [ 80,  80,  80, ...,  46,  50,  50],
#        [ 80,  80,  80, ...,  46,  50,  50],
#        ...,
#        [  0,   0, 164, ...,  58,  56,  50],
#        [  0,   0,   0, ...,  58,  57,  50],
#        [  0,   0,   0, ...,  59,  58,  51]], dtype=uint8)

# %%
plt.imshow(beforedata,cmap = "gray")

# %%
plt.imshow(afterdata,cmap = "gray")
